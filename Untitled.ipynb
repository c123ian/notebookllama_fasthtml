# %%
import pickle

with open('final_rewritten_text_a5d681e7e23d4c54a047e594fed7d790.pkl', 'rb') as file:
    INPUT_PROMPT = pickle.load(file)

# %%
INPUT_PROMPT # should look like
# Out:
# "SPEAKER 1: Welcome to this week's episode of AI Insights, where we explore the latest developments in the field of artificial intelligence. Today, we're going to dive into the fascinating world of knowledge distillation, a methodology that transfers advanced capabilities from leading proprietary Large Language Models, or LLMs, to their open-source counterparts. Joining me on this journey is my co-host, who's new to the topic, and I'll be guiding them through the ins and outs of knowledge distillation. So, let's get started!\n\nSPEAKER 2: Sounds exciting! I've heard of knowledge distillation, but I'm not entirely sure what it's all about. Can you give me a brief overview?\n\nSPEAKER 1: Of course! Knowledge distillation is a technique that enables the transfer of knowledge from a large, complex model, like GPT-4 or Gemini, to a smaller, more efficient model, like LLaMA or Mistral. This process allows the smaller model to learn from the teacher model's output, enabling it to acquire si
# ...

# %%
INPUT_PROMPT
# Out:
# [('Speaker 1',
#   [{'role': 'system',
# ...

# %%
import pickle

with open('dialogue_a5d681e7e23d4c54a047e594fed7d790.pkl', 'rb') as file:
    PODCAST_TEXT = pickle.load(file)

# %%
PODCAST_TEXT
# Out:
# [('Speaker 1',
#   [{'role': 'system',
# ...

# %%
PODCAST_TEXT
# Out:
# 'PODCAST_TEXT = [\n    ("Speaker 1", "Welcome to this week\'s episode of AI Insights, where we explore the latest developments in the field of artificial intelligence. Today, we\'re going to dive into the fascinating world of knowledge distillation, a methodology that transfers advanced capabilities from leading proprietary Large Language Models, or LLMs, to their open-source counterparts."),\n    ("Speaker 2", "Sounds exciting! I\'ve heard of knowledge distillation, but I\'m not entirely sure what it\'s all about. Can you give me a brief overview?"),\n    ("Speaker 1", "Of course! Knowledge distillation is a technique that enables the transfer of knowledge from a large, complex model, like GPT-4 or Gemini, to a smaller, more efficient model, like LLaMA or Mistral. This process allows the smaller model to learn from the teacher model\'s output, enabling it to acquire similar capabilities. For example, think of it like how a student learns by listening to their teacher\'s lectures and
# ...

# %%
import ast
ast.literal_eval(PODCAST_TEXT)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 import ast
# ----> 2 ast.literal_eval(PODCAST_TEXT)
#
# File c:\Users\c123i\anaconda3\envs\mymodal\Lib\ast.py:112, in literal_eval(node_or_string)
#     110                 return left - right
#     111     return _convert_signed_num(node)
# --> 112 return _convert(node_or_string)
#
# File c:\Users\c123i\anaconda3\envs\mymodal\Lib\ast.py:111, in literal_eval.<locals>._convert(node)
#     109         else:
#     110             return left - right
# --> 111 return _convert_signed_num(node)
#
# File c:\Users\c123i\anaconda3\envs\mymodal\Lib\ast.py:85, in literal_eval.<locals>._convert_signed_num(node)
#      83     else:
#      84         return - operand
# ---> 85 return _convert_num(node)
#
# File c:\Users\c123i\anaconda3\envs\mymodal\Lib\ast.py:76, in literal_eval.<locals>._convert_num(node)
# ...

# %%
import pickle

with open('final_podcast_data.pkl', 'rb') as file:
    MY_PODCAST_TEXT = pickle.load(file)

# %%
MY_PODCAST_TEXT
# Out:
# [{'role': 'system',
# ...

# %%
import ast
ast.literal_eval(MY_PODCAST_TEXT)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 2
#       1 import ast
# ----> 2 ast.literal_eval(MY_PODCAST_TEXT)
#
# File ~\anaconda3\Lib\ast.py:110, in literal_eval(node_or_string)
#     108                 return left - right
#     109     return _convert_signed_num(node)
# --> 110 return _convert(node_or_string)
#
# File ~\anaconda3\Lib\ast.py:109, in literal_eval.<locals>._convert(node)
#     107         else:
#     108             return left - right
# --> 109 return _convert_signed_num(node)
#
# File ~\anaconda3\Lib\ast.py:83, in literal_eval.<locals>._convert_signed_num(node)
#      81     else:
#      82         return - operand
# ---> 83 return _convert_num(node)
#
# File ~\anaconda3\Lib\ast.py:74, in literal_eval.<locals>._convert_num(node)
#      72 def _convert_num(node):
# ...

# %%
import pickle

with open('final_podcast_data.pkl', 'rb') as file:
    MY_PODCAST_TEXT_2 = pickle.load(file)

# %%
MY_PODCAST_TEXT_2
# Out:
# [{'role': 'system',
# ...

# %%
import ast
ast.literal_eval(MY_PODCAST_TEXT_2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 2
#       1 import ast
# ----> 2 ast.literal_eval(MY_PODCAST_TEXT_2)
#
# File ~\anaconda3\Lib\ast.py:110, in literal_eval(node_or_string)
#     108                 return left - right
#     109     return _convert_signed_num(node)
# --> 110 return _convert(node_or_string)
#
# File ~\anaconda3\Lib\ast.py:109, in literal_eval.<locals>._convert(node)
#     107         else:
#     108             return left - right
# --> 109 return _convert_signed_num(node)
#
# File ~\anaconda3\Lib\ast.py:83, in literal_eval.<locals>._convert_signed_num(node)
#      81     else:
#      82         return - operand
# ---> 83 return _convert_num(node)
#
# File ~\anaconda3\Lib\ast.py:74, in literal_eval.<locals>._convert_num(node)
#      72 def _convert_num(node):
# ...
